# %% [markdown]
# # Auto Dataset
# Dataset source: PA2

# %%
# first we import the libraries
import utils
import plot_utils
import importlib
import os  # for path

# %%
importlib.reload(utils)  # reload utils to get the updated version
auto_data_fname = os.path.join("input_data", "auto-data-removed-NA.txt")

# %%
# now that its imported we can make a mypytable
auto_data = utils.open_file_to_mypytable(auto_data_fname)
auto_data.remove_rows_with_missing_values()

# %%
importlib.reload(plot_utils)  # reload utils to get the updated version
# Out:
# <module 'plot_utils' from '/Users/benpuryear/Desktop/School/PAs/pa3-Ben10164/plot_utils.py'>

# %%
plot_utils.plot_occurance_bar(auto_data, "cylinders", "cylinders")

# %%
plot_utils.plot_occurance_bar(auto_data, "model year", "model year")

# %%
plot_utils.plot_occurance_bar(auto_data, "origin", "origin")

# %% [markdown]
# ### Step 2

# %%
importlib.reload(plot_utils)  # reload utils to get the updated version
importlib.reload(utils)  # reload utils to get the updated version
auto_data.convert_to_numeric()
auto_data.remove_rows_with_missing_values()
mpg_categorical_list = auto_data.get_column("mpg")
mpg_categorical_list = [utils.get_mpg_rating(x) for x in mpg_categorical_list]

plot_utils.plot_occurance_bar_list(mpg_categorical_list, "mpg rating", "mpg rating")

# %% [markdown]
# ### Part 3

# %%
importlib.reload(plot_utils)  # reload utils to get the updated version
# Out:
# <module 'plot_utils' from '/Users/benpuryear/Desktop/School/PAs/pa3-Ben10164/plot_utils.py'>

# %%
plot_utils.plot_histogram(auto_data.get_column("mpg"), "mpg", "mpg histogram")

# %%
plot_utils.plot_histogram(
    auto_data.get_column("displacement"), "displacement", "displacement histogram"
)

# %%
plot_utils.plot_histogram(
    auto_data.get_column("horsepower"), "horsepower", "horsepower histogram"
)

# %%
plot_utils.plot_histogram(auto_data.get_column("weight"), "weight", "weight histogram")

# %%
plot_utils.plot_histogram(
    auto_data.get_column("acceleration"), "acceleration", "acceleration histogram"
)

# %%
plot_utils.plot_histogram(auto_data.get_column("msrp"), "MSRP", "MSRP histogram")

# %%
importlib.reload(plot_utils)  # reload utils to get the updated version
# Out:
# <module 'plot_utils' from '/Users/benpuryear/Desktop/School/PAs/pa3-Ben10164/plot_utils.py'>

# %%
plot_utils.plot_scatter(auto_data, "displacement", "mpg", "displacement vs mpg")

# %% [markdown]
# * There is a slight correlation for the higher the displacement, the lower the mpg.

# %%
plot_utils.plot_scatter(auto_data, "horsepower", "mpg", "horsepower vs mpg")

# %% [markdown]
# * There is a slight correlation for the higher the horsepower, the lower the mpg.

# %%
plot_utils.plot_scatter(auto_data, "weight", "mpg", "weight vs mpg")

# %% [markdown]
# * This has a very strong correlation where the heavier the car is, the lower the miles per gallon.

# %%
plot_utils.plot_scatter(auto_data, "acceleration", "mpg", "acceleration vs mpg")

# %% [markdown]
# * There is no correlation between the acceleration and the mpg

# %%
plot_utils.plot_scatter(auto_data, "msrp", "mpg", "msrp vs mpg")

# %% [markdown]
# * There is no correlation between msrp and mpg
